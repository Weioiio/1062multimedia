# %%
import numpy as np
import pand as as pd
from keras.utils import np_utils
np.random.seed(10)
# Out:
#   File "<ipython-input-1-29e2638ea67d>", line 2
#     import pand as as pd
#                     ^
# SyntaxError: invalid syntax

# %%
import numpy as np
import pand as pd
from keras.utils import np_utils
np.random.seed(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-830e80d0fdb0> in <module>()
#       1 import numpy as np
# ----> 2 import pand as pd
#       3 from keras.utils import np_utils
#       4 np.random.seed(10)
#
# ModuleNotFoundError: No module named 'pand'

# %%
from keras.datasets import mnist
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-ab413e7a8b2b> in <module>()
# ----> 1 from keras.datasets import mnist
#
# ModuleNotFoundError: No module named 'keras'

# %%
import numpy as np
import pandas as pd
from keras.utils import np_utils
np.random.seed(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-2646a3064830> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from keras.utils import np_utils
#       4 np.random.seed(10)
#
# ModuleNotFoundError: No module named 'keras'

# %%
from keras.datasets import mnist

# %%
(x_train_image, y_train_label), \
(x_test_image, y_test_label) = mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-dbe74b16a98b> in <module>()
# ----> 1 (x_train_image, y_train_label), (x_test_image, y_test_label) = mnist.load_data()
#
# NameError: name 'mnist' is not defined

# %%
import numpy as np
import pandas as pd
from keras.utils import np_utils
np.random.seed(10)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-6-2646a3064830> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from keras.utils import np_utils
#       4 np.random.seed(10)
#
# ModuleNotFoundError: No module named 'keras'

# %%
import numpy as np
import pandas as pd
from keras.utils import np_utils
np.random.seed(10)
# Out:
# C:\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-7-2646a3064830> in <module>()
#       1 import numpy as np
#       2 import pandas as pd
# ----> 3 from keras.utils import np_utils
#       4 np.random.seed(10)
#
# C:\Anaconda3\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# C:\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# C:\Anaconda3\lib\site-packages\keras\backend\__init__.py in <module>()
#      85 elif _BACKEND == 'tensorflow':
#      86     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 87     from .tensorflow_backend import *
#      88 else:
#      89     # Try and load external backend.
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
from keras.datasets import mnist
# Out:
# Using TensorFlow backend.
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-8-ab413e7a8b2b> in <module>()
# ----> 1 from keras.datasets import mnist
#
# C:\Anaconda3\lib\site-packages\keras\__init__.py in <module>()
#       1 from __future__ import absolute_import
#       2
# ----> 3 from . import utils
#       4 from . import activations
#       5 from . import applications
#
# C:\Anaconda3\lib\site-packages\keras\utils\__init__.py in <module>()
#       4 from . import data_utils
#       5 from . import io_utils
# ----> 6 from . import conv_utils
#       7
#       8 # Globally-importable utils.
#
# C:\Anaconda3\lib\site-packages\keras\utils\conv_utils.py in <module>()
#       7 from six.moves import range
#       8 import numpy as np
# ----> 9 from .. import backend as K
#      10
#      11
#
# C:\Anaconda3\lib\site-packages\keras\backend\__init__.py in <module>()
#      85 elif _BACKEND == 'tensorflow':
#      86     sys.stderr.write('Using TensorFlow backend.\n')
# ---> 87     from .tensorflow_backend import *
#      88 else:
#      89     # Try and load external backend.
#
# C:\Anaconda3\lib\site-packages\keras\backend\tensorflow_backend.py in <module>()
#       3 from __future__ import print_function
#       4
# ----> 5 import tensorflow as tf
#       6 from tensorflow.python.framework import ops as tf_ops
#       7 from tensorflow.python.training import moving_averages
#
# ModuleNotFoundError: No module named 'tensorflow'

# %%
(x_train_image, y_train_label), \
(x_test_image, y_test_label) = mnist.load_data()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-dbe74b16a98b> in <module>()
# ----> 1 (x_train_image, y_train_label), (x_test_image, y_test_label) = mnist.load_data()
#
# NameError: name 'mnist' is not defined

# %%
print('train data=',len(x_train_image))
print(' test data=',len(x_test_image))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-840e5446f55f> in <module>()
# ----> 1 print('train data=',len(x_train_image))
#       2 print(' test data=',len(x_test_image))
#
# NameError: name 'x_train_image' is not defined

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+imag
e2[i+1,j,k]+image2 [i,j+1,k] 
                average = sum/5 
                ret_img [i,j,k] = np.uint8(average ) 
        return ret_img
    
img=io.imread('horse.png')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()
# Out:
#   File "<ipython-input-11-fbe99d2c499e>", line 14
#     average = sum/5
#     ^
# IndentationError: unexpected indent

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+imag
e2[i+1,j,k]+image2 [i,j+1,k] 
                average = sum/5 
                ret_img [i,j,k] = np.uint8(average ) 
        return ret_img
    
img=io.imread('horse.png')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()
# Out:
#   File "<ipython-input-12-fbe99d2c499e>", line 14
#     average = sum/5
#     ^
# IndentationError: unexpected indent

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+imag
e2[i+1,j,k]+image2 [i,j+1,k] 
                average = sum/5
                ret_img [i,j,k] = np.uint8(average ) 
        return ret_img
    
img=io.imread('horse.png')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()
# Out:
#   File "<ipython-input-13-72ab75c7d548>", line 14
#     average = sum/5
#     ^
# IndentationError: unexpected indent

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+imag
e2[i+1,j,k]+image2 [i,j+1,k] 
            average = sum/5 
            ret_img [i,j,k] = np.uint8(average ) 
        return ret_img
    
img=io.imread('horse.png')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()
# Out:
#   File "<ipython-input-14-19524ab0c868>", line 14
#     average = sum/5
#     ^
# IndentationError: unexpected indent

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+image2[i+1,j,k]+image2 [i,j+1,k]
                average = sum/5 
                ret_img [i,j,k] = np.uint8(average ) 
                return ret_img
    
img=io.imread('horse.png')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np
    def blendingImages (image1 ,image2 ,startX ,startY ):
        rows1,cols1,dims1=image1.shape 
        rows2,cols2,dims2=image2.shape 
        image11 = np.double(image1) 
        image21 = np.double(image2)
        ret_img = np.uint8(255*np.ones((500,500,3)))
        
        for i in range(0, rows1): 
            for j in range(0,cols1): 
                for k in range(0,3): ret_img [i,j,k] = np.uint8(image11 [i,j,k])
                    
        for i in range(startY+0, startY +rows2): 
            for j in range(startX +0,startX +cols2): 
                if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
                    for k in range(0,3): 
                        ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
                else : 
                    for k in range(0,3): 
                        ret_img [i,j,k] = np.uint8((ret_img [i,j,k]+image21 [i- startY ,j-startX ,k])/2) 
        return ret_img
img=io.imread('horse.png')
img2=io.imread('road.jpg')

startX = 100
startY = 100
img3 = blendingImages(img,img2,startX,startY)
plt.figure(num=1, figsize=(15,15))
plt.subplot(1,3,1)
plt.title('horse')
plt.imshow(img)

plt.subplot(1,3,2)
plt.title('road')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('blend')
plt.imshow(img3)
plt.show()
# Out:
#   File "<ipython-input-17-5973c4ce0522>", line 3
#     import numpy as np def blendingImages (image1 ,image2 ,startX ,startY ):
#                          ^
# SyntaxError: invalid syntax

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blendingImages (image1 ,image2 ,startX ,startY ):
    
    rows1,cols1,dims1=image1.shape 
    rows2,cols2,dims2=image2.shape 
    image11 = np.double(image1) 
    image21 = np.double(image2)
    ret_img = np.uint8(255*np.ones((500,500,3)))
        
    for i in range(0, rows1): 
        for j in range(0,cols1): 
            for k in range(0,3): ret_img [i,j,k] = np.uint8(image11 [i,j,k])
                    
    for i in range(startY+0, startY +rows2): 
        for j in range(startX +0,startX +cols2): 
            if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
            else : 
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8((ret_img [i,j,k]+image21 [i- startY ,j-startX ,k])/2) 
    return ret_img

img=io.imread('horse.png')
img2=io.imread('road.jpg')

startX = 100
startY = 100
img3 = blendingImages(img,img2,startX,startY)
plt.figure(num=1, figsize=(15,15))
plt.subplot(1,3,1)
plt.title('horse')
plt.imshow(img)

plt.subplot(1,3,2)
plt.title('road')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('blend')
plt.imshow(img3)
plt.show()
# Out:
#   File "<ipython-input-18-62d96a62e004>", line 4
#     def blendingImages (image1 ,image2 ,startX ,startY ):
#     ^
# IndentationError: unexpected indent

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blendingImages (image1 ,image2 ,startX ,startY ):
    
    rows1,cols1,dims1=image1.shape 
    rows2,cols2,dims2=image2.shape 
    image11 = np.double(image1) 
    image21 = np.double(image2)
    ret_img = np.uint8(255*np.ones((500,500,3)))
        
    for i in range(0, rows1): 
        for j in range(0,cols1): 
            for k in range(0,3): ret_img [i,j,k] = np.uint8(image11 [i,j,k])
                    
    for i in range(startY+0, startY +rows2): 
        for j in range(startX +0,startX +cols2): 
            if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
            else : 
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8((ret_img [i,j,k]+image21 [i- startY ,j-startX ,k])/2) 
    return ret_img

img=io.imread('horse.png')
img2=io.imread('road.jpg')

startX = 100
startY = 100
img3 = blendingImages(img,img2,startX,startY)
plt.figure(num=1, figsize=(15,15))
plt.subplot(1,3,1)
plt.title('horse')
plt.imshow(img)

plt.subplot(1,3,2)
plt.title('road')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('blend')
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-19-dca9e51327f1> in <module>()
#      30 startX = 100
#      31 startY = 100
# ---> 32 img3 = blendingImages(img,img2,startX,startY)
#      33 plt.figure(num=1, figsize=(15,15))
#      34 plt.subplot(1,3,1)
#
# <ipython-input-19-dca9e51327f1> in blendingImages(image1, image2, startX, startY)
#      17     for i in range(startY+0, startY +rows2):
#      18         for j in range(startX +0,startX +cols2):
# ---> 19             if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
#      20                 for k in range(0,3):
#      21                     ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
#
# IndexError: index 500 is out of bounds for axis 1 with size 500

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+image2[i+1,j,k]+image2 [i,j+1,k]
                average = sum/5 
                ret_img [i,j,k] = np.uint8(average ) 
                return ret_img
    
img=io.imread('road.jpg')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blendingImages (image1 ,image2 ,startX ,startY ):
    
    rows1,cols1,dims1=image1.shape 
    rows2,cols2,dims2=image2.shape 
    image11 = np.double(image1) 
    image21 = np.double(image2)
    ret_img = np.uint8(255*np.ones((500,500,3)))
        
    for i in range(0, rows1): 
        for j in range(0,cols1): 
            for k in range(0,3): ret_img [i,j,k] = np.uint8(image11 [i,j,k])
                    
    for i in range(startY+0, startY +rows2): 
        for j in range(startX +0,startX +cols2): 
            if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
            else : 
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8((ret_img [i,j,k]+image21 [i- startY ,j-startX ,k])/2) 
    return ret_img

img=io.imread('horse.png')
img2=io.imread('roads.jpg')

startX = 100
startY = 100
img3 = blendingImages(img,img2,startX,startY)
plt.figure(num=1, figsize=(15,15))
plt.subplot(1,3,1)
plt.title('horse')
plt.imshow(img)

plt.subplot(1,3,2)
plt.title('road')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('blend')
plt.imshow(img3)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-21-08a3b14f42cd> in <module>()
#      30 startX = 100
#      31 startY = 100
# ---> 32 img3 = blendingImages(img,img2,startX,startY)
#      33 plt.figure(num=1, figsize=(15,15))
#      34 plt.subplot(1,3,1)
#
# <ipython-input-21-08a3b14f42cd> in blendingImages(image1, image2, startX, startY)
#      17     for i in range(startY+0, startY +rows2):
#      18         for j in range(startX +0,startX +cols2):
# ---> 19             if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
#      20                 for k in range(0,3):
#      21                     ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
#
# IndexError: index 500 is out of bounds for axis 1 with size 500

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blurImage (image): 
    rows,cols,dims=image.shape 
    image2 = np.double (image) 
    ret_img = np.uint8(255*np.ones((rows,cols,dims))) 
    for i in range(1, rows-1):
        for j in range(1,cols-1): 
            for k in range(0,3): 
                sum = image2 [i,j,k]+image2 [i-1,j,k]+image2 [i,j-1,k]+image2[i+1,j,k]+image2 [i,j+1,k]
                average = sum/5 
                ret_img [i,j,k] = np.uint8(average ) 
                return ret_img
    
img=io.imread('roads.jpg')

plt.figure (num=0, figsize =(8,8)) 
plt.subplot (1,2,1) 
plt.title('origin image' ) 
plt.imshow (img)

img2 = blurImage(img) 
plt.subplot (1,2,2) 
plt.title('canvas result' ) 
plt.imshow (img2) 
plt.show()

# %%
from skimage import io 
import matplotlib.pyplot as plt 
import numpy as np

def blendingImages (image1 ,image2 ,startX ,startY ):
    
    rows1,cols1,dims1=image1.shape 
    rows2,cols2,dims2=image2.shape 
    image11 = np.double(image1) 
    image21 = np.double(image2)
    ret_img = np.uint8(255*np.ones((500,500,3)))
        
    for i in range(0, rows1): 
        for j in range(0,cols1): 
            for k in range(0,3): ret_img [i,j,k] = np.uint8(image11 [i,j,k])
                    
    for i in range(startY+0, startY +rows2): 
        for j in range(startX +0,startX +cols2): 
            if (ret_img [i,j,0] == 255) and (ret_img [i,j,1] == 255) and (ret_img[i,j,2] == 255):
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8(image21 [i-startY ,j-startX , k])
            else : 
                for k in range(0,3): 
                    ret_img [i,j,k] = np.uint8((ret_img [i,j,k]+image21 [i- startY ,j-startX ,k])/2) 
    return ret_img

img=io.imread('horse.png')
img2=io.imread('road.jpg')

startX = 100
startY = 100
img3 = blendingImages(img,img2,startX,startY)
plt.figure(num=1, figsize=(15,15))
plt.subplot(1,3,1)
plt.title('horse')
plt.imshow(img)

plt.subplot(1,3,2)
plt.title('road')
plt.imshow(img2)
plt.subplot(1,3,3)
plt.title('blend')
plt.imshow(img3)
plt.show()
